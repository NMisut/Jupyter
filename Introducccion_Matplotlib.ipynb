# %% [markdown]
# <a href="https://colab.research.google.com/github/NMisut/Jupyter/blob/main/Introducccion_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejemplos con librería Matplotlib
#
# Empezamos por importar el subpaquete pyplot, que es el que realmente vamos a utilizar, desde matplotlib

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# Empezamos por algo sencillo, la figura que representa los valores de una función y (Producto Interior Bruto) para una sucesión de datos en x (años)

# %%
years = [1950,1960,1970,1980,1990,2000,2010]
gdp = [300.2,543.3,1075.9,2862.5,5979.6,10289.7,14958.3]

# %%
plt.plot(years,gdp,color='green',marker='o',linestyle='solid')
plt.title("Nominal GDP")

plt.ylabel("Billions of $")
# Out:
# Text(0, 0.5, 'Billions of $')

# %% [markdown]
# Aunque en Colab no es necesario, siempre que programemos un script para ejecutarlo en un IDE, tenemos que añadir show() al final.*texto en cursiva*

# %%
plt.style.use('classic')

plt.plot(years,gdp,color='green',marker='o',linestyle='solid')
plt.title("Nominal GDP")

plt.ylabel("Billions of $")
plt.show()

# %% [markdown]
# Podemos utilizar distintos temas para los estilos de los gráficos

# %%
plt.style.use('ggplot')

plt.plot(years,gdp,color='red',marker='^', markersize=12,linestyle='dashed')
plt.title("Nominal GDP")

plt.ylabel("Billions of $")
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Si queremos volver al estilo por defecto, usamos 'default' con el método style.use
#
# Y también podemos usar las abreviaturas de color y estilo de marcador, como 'bo' para blue - marcador o

# %%
plt.style.use('default')

plt.plot(years,gdp,'gx',linestyle='solid')
plt.title("Nominal GDP")

plt.ylabel("Billions of $")
plt.show()

# %% [markdown]
# En vez del método show(), también es común ver la función 'inline' que inserta la imagen en el notebook en vez de "abrir" una ventana con la representación (que sería el evento si ejecutásemos un script con 'show'

# %%
# %matplotlib inline

plt.plot(years,gdp,'bo',linestyle='solid')
plt.title("Nominal GDP")

plt.ylabel("Billions of $")
# Out:
# Text(0, 0.5, 'Billions of $')

# %% [markdown]
# Si queremos dibujar varias líneas, tenemos que llamar a la función plot por cada representación

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]

xs = [i for i, _ in enumerate(variance)]

# We can make multiple calls to plt.plot
# to show multiple series on the same chart

plt.plot(xs, variance, 'g-', label='variance') # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # red dot-dashed line
plt.plot(xs, total_error, 'b:', label='total error') # blue dotted line

# Because we've assigned labels to each series,
# we can get a legend for free (loc=9 means "top center")

plt.legend(loc=9)
plt.xlabel("model complexity")
plt.xticks([])
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# Otra opción para representar varias líneas en el mismo gráfico:

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## Representación de funciones analíticas

# %%
import matplotlib.pyplot as plt

# Pasa valores para x generados por range y calcula los de y con la expresión cuadrática
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()

ax.scatter(x_values, y_values, s=10)

ax.set_title("Square Numbers", fontsize=24) 
ax.set_xlabel("Value", fontsize=14) 
ax.set_ylabel("Square of Value", fontsize=14)

# Fijamos el rango de los ejes
ax.axis([0, 1100, 0, 1100000]) 

plt.show()

# %% [markdown]
# El parámetro cmap o colormap especifica un tema de color para la distribución de puntos. En este ejemplo, utilizamos, para el parámetro del color c, una distribución de valores basada en la variación de y, de manera que obtenemos un degradado.

# %%
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()

# Pasamos los valores de y a c
# Con cmap, indicamos que queremos un "colormap" e indicamos el patrón Blues

ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)

ax.set_title("Square Numbers", fontsize=24) 
ax.set_xlabel("Value", fontsize=14) 
ax.set_ylabel("Square of Value", fontsize=14)

ax.axis([0, 1100, 0, 1100000]) 

plt.show()

# %% [markdown]
# Otra función muy utilizada es la que permite representar diagramas de barras

# %%
movies = ["Annie Hall", "Ben Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
plt.bar(range(len(movies)), num_oscars)
plt.title("Mis pelis favoritas")
plt.ylabel("Oscars ganados")

plt.xticks(range(len(movies)), movies)

plt.show()

# %% [markdown]
# En este ejemplo, creamos un histograma a base de diagrama de barras, pero es más práctico utilizar directamente la funcion hist()

# %%
from collections import Counter

notas = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

# Agrupamos las notas en cada decena, y para 100, la pasamos al percentil de 90.

histograma = Counter(min(nota // 10 * 10, 90) for nota in notas)

plt.bar([x + 5 for x in histograma.keys()], # Damos margen de 5 a las barras
          histograma.values(), 
          10, # El ancho de cada barra será de 10
          edgecolor=(0, 0, 0)) # Ponemos borde negro a cada barra

plt.axis([-5, 105, 0, 5]) # Damos margen a la escala por los lados

plt.xticks([10 * i for i in range(11)])
plt.xlabel("Nota")
plt.ylabel("Estudiantes")
plt.title("Histograma notas exámenes")
plt.show()

# %%
plt.hist(notas,bins=10)

plt.axis([-5, 105, 0, 5]) 

plt.xticks([10 * i for i in range(11)]) 
plt.xlabel("Nota")
plt.ylabel("Estudiantes")
plt.title("Histograma notas exámenes")
plt.show()

# %% [markdown]
# ¡Ojo con plt.axis y malas prácticas de representación!

# %%
mentions = [500, 505]
years = [2017, 2018]

plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 499, 506])
plt.title("Look at the 'Huge' Increase!")

plt.show()

# %%
plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")


plt.axis([2016.5, 2018.5, 0, 550])
plt.title("Not So Huge Anymore")
plt.show()

# %% [markdown]
# Probamos ahora la representación de diagrama de puntos (Scatterplot)

# %%
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

# Ponemos una etiqueta a cada punto
for label, friend_count, minute_count in zip(labels, friends, minutes):
  plt.annotate(label,
              xy=(friend_count, minute_count), # cada etiqueta con su punto
              xytext=(5, -5), # separamos el texto del punto
              textcoords='offset points')

plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()

# %% [markdown]
# Ejemplo de ejes no comparables. Si dejamos que pyplot escale solo los ejes, tomará el intervalo mínimo necesario para cada variable, pero eso puede hacer que no podamos tener la visión de la evolución de una variable respecto de la otra. Para eso es mejor que los ejes sean comparables

# %%
notas_1A = [ 99, 90, 85, 97, 80]
notas_1B = [100, 85, 60, 90, 70]

plt.scatter(notas_1A, notas_1B)

plt.title("Ejes no comparables")
plt.xlabel("notas 1ºA")
plt.ylabel("notas 1ºB")
plt.show()

# %% [markdown]
# Añadiendo el argumento 'equal', se aplica la misma escala a ambos ejes para poder ver que la variedad de notas de 1ºB ha sido mucho más ámplia.

# %%
plt.axis('equal')
plt.scatter(notas_1A, notas_1B)

plt.title("Ejes no comparables")
plt.xlabel("notas 1ºA")
plt.ylabel("notas 1ºB")
plt.show()

# %% [markdown]
# Podemos utilizar claves de conjuntos de datos para atributos de la imagen, como la selección del color o del tamaño de los puntos.

# %%
plt.style.use('default')

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# Si queremos guardar el gráfico como archivo, usamos savefig

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')

plt.savefig('my_scatterplot.png',bbox_inches='tight')

# %% [markdown]
# Una función muy interesante, es Scattergeo, que nos permite posicionar puntos en función de sus coordenadas sobre la representación de un mapa y permite cierto grado de interactividad.

# %%
import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df['text'] = df['airport'] + '' + df['city'] + ', ' + df['state'] + '' + 'Arrivals: ' + df['cnt'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df['long'],
        lat = df['lat'],
        text = df['text'],
        mode = 'markers',
        marker_color = df['cnt'],
        ))

fig.update_layout(
        title = 'Most trafficked US airports<br>(Hover for airport names)',
        geo_scope='usa',
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Licencia CC BY SA
